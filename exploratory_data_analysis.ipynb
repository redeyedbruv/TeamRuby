# %% [markdown]
# i'm gonna import some libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# i'm goiong to start loading my data from my github page to pandas dataframe

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/contact_settings.csv'

# %%
cns_settings = ['id', 'user_id', 'email', 'display_images', 'created_at', 'updated_at']
contact = pd.read_csv(url, names = cns_settings)

# %%
contact.head()
# Out:
#    id  user_id  ... created_at updated_at
# 0   1       78  ...        NaN        NaN
# 1   2       90  ...        NaN        NaN
# 2   3       53  ...        NaN        NaN
# 3   4      133  ...        NaN        NaN
# 4   5       92  ...        NaN        NaN
#
# [5 rows x 6 columns]

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/extfeeds.csv'

# %%
ext_column =['id', 'user_id', 'site', 'site_image', 'title', 'desc', 'link', 'date', 'image', 'created_at', 'updated_at', 'tags']
extfeed = pd.read_csv(url, names=ext_column)

# %%
extfeed.head()
# Out:
#      id  user_id           site  ... created_at updated_at tags
# 0  2839        2  Elijah Okokon  ...        NaN        NaN  NaN
# 1  2840        2  Elijah Okokon  ...        NaN        NaN  NaN
# 2  2841        2  Elijah Okokon  ...        NaN        NaN  NaN
# 3  2842        2  Elijah Okokon  ...        NaN        NaN  NaN
# 4  2843        2  Elijah Okokon  ...        NaN        NaN  NaN
#
# [5 rows x 12 columns]

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/following.csv'

# %%
fol_column =['user_id', 'follower_id', 'status']
following = pd.read_csv(url, names=fol_column)

# %%
following.head
# Out:
#       user_id  follower_id  status
# 0           3            6       1
# 1           6            3       1
# 2           3            2       1
# 3           3            7       1
# 4           7            2       1
# 5           7            3       1
# 6           9            2       1
# 7           9            3       1
# 8           9            7       1
# 9           8            9       1
# 10          4            9       1
# 11          3            9       1
# 12          1            7       1
# 13          1            3       1
# 14          4            2       1
# 15          4            1       1
# 16          3            2       1
# 17          3            1       1
# 18         11            7       1
# 19          7           11       1
# 20         17            7       1
# 21         20            7       1
# 22         20            3       1
# 23         20            9       1
# 24         23            7       1
# 25         25            7       1
# ...

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/maillists.csv'

# %%
mlt_column =['id', 'email', 'created_at', 'updated_at']

mailist = pd.read_csv(url, names=mlt_column)

# %%
mailist.head(5)
# Out:
#    id                    email  created_at  updated_at
# 0   1        ubarab85@live.com         NaN         NaN
# 1   2     detoun4med@gmail.com         NaN         NaN
# 2   3       emmanuel@gmail.com         NaN         NaN
# 3   4       ifydechu@gmail.com         NaN         NaN
# 4   5  olaiwolaahmod@gmail.com         NaN         NaN

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/posts.csv'

# %%
pst_column =['id', 'user_id','title', 'content', 'tags', 'slugs', 'created_at', 'updated_at', 'image', 'status_id', 'action', 'post_id']
post = pd.read_csv(url, names=pst_column)

# %%
post.drop([ 'slugs','created_at', 'updated_at', 'image','action'], axis=1, inplace=True)

# %%
post.head(5)
# Out:
#    id  user_id  ... status_id post_id
# 0   1     2077  ...       NaN     NaN
# 1   2     1719  ...       NaN     NaN
# 2   4     1310  ...       NaN     NaN
# 3   6     1787  ...       NaN     NaN
# 4   7      167  ...       NaN     NaN
#
# [5 rows x 7 columns]

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/thoughts.csv'

# %%
tht_column =['id', 'user_id', 'content', 'created_at', 'updated_at']
thoughts = pd.read_csv(url, names=tht_column)

# %%
thoughts.head()
# Out:
#    id  user_id  ...           created_at           updated_at
# 0   1     2195  ...  2019-08-26 13:30:26  2019-08-26 13:30:26
# 1   2      148  ...  2019-08-26 13:57:35  2019-08-26 13:57:35
# 2   3     2212  ...  2019-08-26 14:35:41  2019-08-26 14:35:41
# 3   4        1  ...  2019-08-26 15:12:07  2019-08-26 15:12:07
# 4   5     2223  ...  2019-08-26 15:24:55  2019-08-26 15:24:55
#
# [5 rows x 5 columns]

# %%
url = 'https://raw.githubusercontent.com/abigailsleek/BEGINNING/master/users.csv'

# %%
usr_names = ['user_id', 'name', 'username', 'email', 'image', 'provider', 'provider_id', 'password', 'remember_token', 'created_at', 'updated_at', 'short_bio']
users = pd.read_csv(url, names = usr_names)

# %%
users.drop(['password', 'remember_token', 'provider', 'provider_id','image', 'created_at', 'updated_at'], axis=1, inplace=True)

# %%
users.head(5)
# Out:
#    user_id  ...                                          short_bio
# 0        1  ...               Software Developer | DevOPs Engineer
# 1        2  ...                                      Web Developer
# 2        3  ...  Front End Developer | React Developer | Mentor...
# 3        4  ...  | Software Developer | DevOps Engineer | @linu...
# 4        5  ...            I Am lamar and you don't think am real?
#
# [5 rows x 5 columns]

# %% [markdown]
# so i want to merge tables now

# %%
df = pd.merge(post,following, on='user_id')

# %%
df.head()
# Out:
#    id  user_id   title  ... post_id follower_id  status
# 0   7      167  Task 2  ...     NaN         290       1
# 1   7      167  Task 2  ...     NaN        1235       1
# 2   7      167  Task 2  ...     NaN         107       1
# 3   7      167  Task 2  ...     NaN         101       1
# 4   7      167  Task 2  ...     NaN           7       1
#
# [5 rows x 9 columns]

# %% [markdown]
# i'm also gonna merge usr to fol

# %%
df6 =pd.merge(users,following, on='user_id')

# %%
df6.head()
# Out:
#    user_id                name  ... follower_id status
# 0        1  Eniayomi Oluwaseyi  ...           7      1
# 1        1  Eniayomi Oluwaseyi  ...           3      1
# 2        1  Eniayomi Oluwaseyi  ...           4      0
# 3        2       Elijah Okokon  ...           7      1
# 4        3        Jeffrey Ogah  ...           6      1
#
# [5 rows x 7 columns]

# %% [markdown]
# now i am going to carry out some Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %% [markdown]
# **next** im going to try to get the average value of followers

# %%
df.groupby('title')['follower_id'].mean().sort_values(ascending=False).head()
# Out:
# title
# Thoughts on the Hng Internship                                      2097.0
# Hng Internship CV to Html Task                                      2097.0
# Notes on the HNG internship                                         2097.0
# BABY STEPS TO BECOMING A PROGRAMMER                                 1875.0
# OVERVIEW OF MY HNG PRE-INTERNSHIP EXPERIENCE: THE JOURNEY SO FAR    1875.0
# Name: follower_id, dtype: float64

# %%
df.groupby('title')['follower_id'].count().sort_values(ascending=False).head(6)
# Out:
# title
# My First Language!!              105
# What have done so far on HTML    104
# what have done so far on HTML    104
# THINGS HAVE LEARNT SO FAR        104
# ochem                            104
# A date with HTML                  86
# Name: follower_id, dtype: int64

# %%
df6.groupby('name')['follower_id'].mean().sort_values(ascending=False).head()
# Out:
# name
# okpako moses          2097.0
# Adebayo Ilerioluwa    1926.0
# Johnbosco Ibemere     1926.0
# Yuns Momodu           1890.0
# peta idehen           1875.0
# Name: follower_id, dtype: float64

# %%
df6.groupby('name')['follower_id'].count().sort_values(ascending=False).head(7)
# Out:
# name
# ukadike ochem               104
# Amadi Onengiye Williams      86
# francisca amaka              40
# Idongesit Patrick Inyang     39
# Kehinde olatubosun           39
# Kingsley Umujeyan            38
# David Adedeji                35
# Name: follower_id, dtype: int64

# %%
forposts = pd.DataFrame(df.groupby('title')['follower_id'].mean())

# %%
forposts.head()
# Out:
#                                                     follower_id
# title
# 5 steps to coding                                      6.000000
# A CHINESE VILLAGER WHO SELLS MORE SOFTWARE DAIL...     5.800000
# A Tourist Centre in Lagos' Capital City              493.625000
# A Trip To Iceland                                    162.000000
# A couple numeronyms in tech                          661.666667

# %%
forposts['no of posts'] = pd.DataFrame(df.groupby('title')['follower_id'].count())

# %%
forposts.head(10)
# Out:
#                                                     follower_id  no of posts
# title
# 5 steps to coding                                      6.000000            1
# A CHINESE VILLAGER WHO SELLS MORE SOFTWARE DAIL...     5.800000            5
# A Tourist Centre in Lagos' Capital City              493.625000            8
# A Trip To Iceland                                    162.000000            4
# A couple numeronyms in tech                          661.666667            3
# A date with HTML                                     532.534884           86
# A giant leap to a better approach..                  886.642857           28
# ARE YOU CAPABLE OF BEING RUTHLESS TO GET AHEAD?        5.500000            4
# About My HTML Task                                   848.300000           10
# About bold positivity                                175.666667            6

# %%
forfollow = pd.DataFrame(df6.groupby('name')['follower_id'].mean())

# %%
forfollow.head()
# Out:
#                       follower_id
# name
# 'Damilola Taylor         3.000000
# 7 Cowries Media       1019.000000
# ABDULKAREEM MUSTAPHA   419.833333
# ADEALA Victor          600.000000
# ADEBAYO OLUWASEUN        6.000000

# %%
forfollow['no of follows'] = pd.DataFrame(df6.groupby('name')['follower_id'].count())

# %%
forfollow.head(6)
# Out:
#                            follower_id  no of follows
# name
# 'Damilola Taylor              3.000000              1
# 7 Cowries Media            1019.000000              2
# ABDULKAREEM MUSTAPHA        419.833333              6
# ADEALA Victor               600.000000              8
# ADEBAYO OLUWASEUN             6.000000              1
# ADEDOYIN BUSOLA ELIZABETH     6.000000              1

# %% [markdown]
# im going to plot some histograms with the above data

# %%
plt.figure(figsize=(20,10))
forposts['no of posts'].hist(bins=70)

# %%
plt.figure(figsize=(20,10))
forposts['follower_id'].hist(bins=50)

# %%
plt.figure(figsize=(20,10))
forfollow['no of follows'].hist(bins=70)

# %%
plt.figure(figsize=(25,15))
forfollow['follower_id'].hist(bins=50)

# %% [markdown]
# now i am going to carry out a joint plot to help get a combination of scattered plots

# %%
sns.jointplot(x='follower_id', y='no of posts', data=forposts, alpha=0.45)

# %%
sns.jointplot(x='follower_id', y='no of follows', data=forfollow, alpha=0.3)

# %% [markdown]
# im going to create a matrix that has title on one axis and postid

# %%
postmat =df.pivot_table(index='user_id', columns='title', values='follower_id')

# %%
postmat
# Out:
# title    5 steps to coding  ...  with picture
# user_id                     ...
# 1                      NaN  ...           NaN
# 2                      NaN  ...           7.0
# 3                      NaN  ...           NaN
# 4                      NaN  ...           NaN
# 6                      NaN  ...           NaN
# 7                      NaN  ...           NaN
# 9                      NaN  ...           NaN
# 24                     NaN  ...           NaN
# 29                     NaN  ...           NaN
# 45                     NaN  ...           NaN
# 46                     NaN  ...           NaN
# 47                     NaN  ...           NaN
# 48                     NaN  ...           NaN
# 49                     NaN  ...           NaN
# 54                     NaN  ...           NaN
# 57                     NaN  ...           NaN
# 72                     NaN  ...           NaN
# 92                     NaN  ...           NaN
# 93                     NaN  ...           NaN
# ...

# %%
forposts.sort_values('no of posts', ascending=False)
# Out:
#                                                     follower_id  no of posts
# title
# My First Language!!                                  777.333333          105
# ochem                                                846.730769          104
# THINGS HAVE LEARNT SO FAR                            846.730769          104
# What have done so far on HTML                        846.730769          104
# what have done so far on HTML                        846.730769          104
# A date with HTML                                     532.534884           86
# Posts or Thoughts?                                   532.534884           86
# StartNG and a Prosaic Beginner                       532.534884           86
# task 2                                               537.200000           60
# CSS is a Whole new Level                             777.333333           60
# HNG Task 2                                           961.000000           50
# ...

# %%
MyFirstLanguage_user_forposts = postmat['My First Language!!']
ochem_user_forposts = postmat['ochem']

# %%
MyFirstLanguage_user_forposts
# Out:
# user_id
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 6      NaN
# 7      NaN
# 9      NaN
# 24     NaN
# 29     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN
# 54     NaN
# 57     NaN
# 72     NaN
# 92     NaN
# 93     NaN
# 116    NaN
# 132    NaN
# 151    NaN
# 154    NaN
# 158    NaN
# 160    NaN
# 167    NaN
# 168    NaN
# 173    NaN
# 175    NaN
# 218    NaN
#         ..
# 1413   NaN
# 1426   NaN
# 1439   NaN
# 1442   NaN
# 1451   NaN
# 1466   NaN
# 1487   NaN
# 1564   NaN
# 1591   NaN
# 1635   NaN
# 1650   NaN
# 1653   NaN
# 1667   NaN
# 1743   NaN
# 1799   NaN
# 1801   NaN
# 1805   NaN
# 1825   NaN
# 1840   NaN
# 1859   NaN
# 1883   NaN
# 1886   NaN
# 1910   NaN
# 1947   NaN
# 1985   NaN
# 2040   NaN
# 2112   NaN
# 2135   NaN
# 2228   NaN
# 2240   NaN
# Name: My First Language!!, Length: 151, dtype: float64

# %%
similar_to_MyFirstLanguage = postmat.corrwith(MyFirstLanguage_user_forposts)
similar_to_ochem = postmat.corrwith(ochem_user_forposts)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_MyFirstLanguage = pd.DataFrame(similar_to_MyFirstLanguage, columns=['Correlation'])
corr_MyFirstLanguage.dropna(inplace=True)

# %%
corr_MyFirstLanguage
# Out:
# Empty DataFrame
# Columns: [Correlation]
# Index: []

# %%
corr_MyFirstLanguage.sort_values('Correlation', ascending=False)
# Out:
# Empty DataFrame
# Columns: [Correlation]
# Index: []

# %%
followmat =df6.pivot_table(index='user_id', columns='name', values='follower_id')

# %%
followmat
# Out:
# name     'Damilola Taylor  7 Cowries Media  ...  wanapere akpos  yomi Awoyemi
# user_id                                     ...
# 1                     NaN              NaN  ...             NaN           NaN
# 2                     NaN              NaN  ...             NaN           NaN
# 3                     NaN              NaN  ...             NaN           NaN
# 4                     NaN              NaN  ...             NaN           NaN
# 6                     NaN              NaN  ...             NaN           NaN
# 7                     NaN              NaN  ...             NaN           NaN
# 8                     NaN              NaN  ...             NaN           NaN
# 9                     NaN              NaN  ...             NaN           NaN
# 11                    NaN              NaN  ...             NaN           NaN
# 15                    NaN              NaN  ...             NaN           NaN
# ...

# %%
forfollow.sort_values('no of follows', ascending=False)
# Out:
#                           follower_id  no of follows
# name
# ukadike ochem              846.730769            104
# Amadi Onengiye Williams    532.534884             86
# francisca amaka            863.825000             40
# Idongesit Patrick Inyang   452.974359             39
# Kehinde olatubosun        1242.923077             39
# Kingsley Umujeyan          439.157895             38
# David Adedeji              622.514286             35
# Rita Nzere                 348.787879             33
# M                          818.093750             32
# Angela Egerega             665.531250             32
# Peace Onyekachi            893.000000             28
# Chiamaka Honor Osuji       756.615385             26
# Emmanuel Ezeako            452.538462             26
# Timothy Mayor             1091.153846             26
# Ibrahim Gana               483.240000             25
# Omolola Richard           1156.720000             25
# Oyelaja Hussein            645.125000             24
# ...

# %%
ukadikeochem_user_forfollow = followmat['ukadike ochem']
o_user_forfollow = followmat['ochem']

# %%
t

# %% [markdown]
# working with follower_id has not been progressive so i will have to rearrange my tables and remerge to get better results.
